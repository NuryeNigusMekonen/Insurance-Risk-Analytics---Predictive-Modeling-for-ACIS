# %%
import pandas as pd

file_path = '../data/machineLearningRating_v3.txt'
df = pd.read_csv(
    file_path,
    sep='|',               
    encoding='utf-8',        
    engine='python',
    on_bad_lines='skip'      
)
print("Shape:", df.shape)
df.head(3)
# Out:
# Shape: (1000098, 52)
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...         ExcessSelected CoverCategory   CoverType  \
# 0  Current account  ...  Mobility - Windscreen    Windscreen  Windscreen
# 1  Current account  ...  Mobility - Windscreen    Windscreen  Windscreen
# 2  Current account  ...  Mobility - Windscreen    Windscreen  Windscreen
#
#              CoverGroup              Section                          Product  \
# 0  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 1  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 2  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
#
#   StatutoryClass StatutoryRiskType  TotalPremium TotalClaims
# 0     Commercial     IFRS Constant     21.929825         0.0
# 1     Commercial     IFRS Constant     21.929825         0.0
# 2     Commercial     IFRS Constant      0.000000         0.0
#
# [3 rows x 52 columns]

# %%
df.info(memory_usage='deep')
import numpy as np

# Quick type check
df.info()

# Missing values by column
missing_summary = df.isnull().sum().sort_values(ascending=False)
missing_pct = (missing_summary / len(df)) * 100
missing_df = pd.DataFrame({
    'missing_count': missing_summary,
    'missing_percent': missing_pct
})
print(missing_df[missing_df.missing_count > 0].head(10))  # Top missing columns

# Detect mixed types (object columns that should be numeric, etc.)
mixed_type_cols = [col for col in df.columns if df[col].apply(type).nunique() > 1]
print("Columns with mixed types:", mixed_type_cols)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
#  13  Province                  1000098 non-null  object
#  14  PostalCode                1000098 non-null  int64
#  15  MainCrestaZone            1000098 non-null  object
#  16  SubCrestaZone             1000098 non-null  object
#  17  ItemType                  1000098 non-null  object
#  18  mmcode                    999546 non-null   float64
#  19  VehicleType               999546 non-null   object
#  20  RegistrationYear          1000098 non-null  int64
#  21  make                      999546 non-null   object
#  22  Model                     999546 non-null   object
#  23  Cylinders                 999546 non-null   float64
#  24  cubiccapacity             999546 non-null   float64
#  25  kilowatts                 999546 non-null   float64
#  26  bodytype                  999546 non-null   object
#  27  NumberOfDoors             999546 non-null   float64
#  28  VehicleIntroDate          999546 non-null   object
#  29  CustomValueEstimate       220456 non-null   float64
#  30  AlarmImmobiliser          1000098 non-null  object
#  31  TrackingDevice            1000098 non-null  object
#  32  CapitalOutstanding        1000096 non-null  object
#  33  NewVehicle                846803 non-null   object
#  34  WrittenOff                358197 non-null   object
#  35  Rebuilt                   358197 non-null   object
#  36  Converted                 358197 non-null   object
#  37  CrossBorder               698 non-null      object
#  38  NumberOfVehiclesInFleet   0 non-null        float64
#  39  SumInsured                1000098 non-null  float64
#  40  TermFrequency             1000098 non-null  object
#  41  CalculatedPremiumPerTerm  1000098 non-null  float64
#  42  ExcessSelected            1000098 non-null  object
#  43  CoverCategory             1000098 non-null  object
#  44  CoverType                 1000098 non-null  object
#  45  CoverGroup                1000098 non-null  object
#  46  Section                   1000098 non-null  object
#  47  Product                   1000098 non-null  object
#  48  StatutoryClass            1000098 non-null  object
#  49  StatutoryRiskType         1000098 non-null  object
#  50  TotalPremium              1000098 non-null  float64
#  51  TotalClaims               1000098 non-null  float64
# dtypes: bool(1), float64(11), int64(4), object(36)
# memory usage: 2.1 GB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
#  13  Province                  1000098 non-null  object
#  14  PostalCode                1000098 non-null  int64
#  15  MainCrestaZone            1000098 non-null  object
#  16  SubCrestaZone             1000098 non-null  object
#  17  ItemType                  1000098 non-null  object
#  18  mmcode                    999546 non-null   float64
#  19  VehicleType               999546 non-null   object
#  20  RegistrationYear          1000098 non-null  int64
#  21  make                      999546 non-null   object
#  22  Model                     999546 non-null   object
#  23  Cylinders                 999546 non-null   float64
#  24  cubiccapacity             999546 non-null   float64
#  25  kilowatts                 999546 non-null   float64
#  26  bodytype                  999546 non-null   object
#  27  NumberOfDoors             999546 non-null   float64
#  28  VehicleIntroDate          999546 non-null   object
#  29  CustomValueEstimate       220456 non-null   float64
#  30  AlarmImmobiliser          1000098 non-null  object
#  31  TrackingDevice            1000098 non-null  object
#  32  CapitalOutstanding        1000096 non-null  object
#  33  NewVehicle                846803 non-null   object
#  34  WrittenOff                358197 non-null   object
#  35  Rebuilt                   358197 non-null   object
#  36  Converted                 358197 non-null   object
#  37  CrossBorder               698 non-null      object
#  38  NumberOfVehiclesInFleet   0 non-null        float64
#  39  SumInsured                1000098 non-null  float64
#  40  TermFrequency             1000098 non-null  object
#  41  CalculatedPremiumPerTerm  1000098 non-null  float64
#  42  ExcessSelected            1000098 non-null  object
#  43  CoverCategory             1000098 non-null  object
#  44  CoverType                 1000098 non-null  object
#  45  CoverGroup                1000098 non-null  object
#  46  Section                   1000098 non-null  object
#  47  Product                   1000098 non-null  object
#  48  StatutoryClass            1000098 non-null  object
#  49  StatutoryRiskType         1000098 non-null  object
#  50  TotalPremium              1000098 non-null  float64
#  51  TotalClaims               1000098 non-null  float64
# dtypes: bool(1), float64(11), int64(4), object(36)
# memory usage: 390.1+ MB
#                          missing_count  missing_percent
# NumberOfVehiclesInFleet        1000098       100.000000
# CrossBorder                     999400        99.930207
# CustomValueEstimate             779642        77.956560
# Rebuilt                         641901        64.183810
# Converted                       641901        64.183810
# WrittenOff                      641901        64.183810
# NewVehicle                      153295        15.327998
# Bank                            145961        14.594670
# AccountType                      40232         4.022806
# Gender                            9536         0.953507
# Columns with mixed types: ['Bank', 'AccountType', 'MaritalStatus', 'Gender', 'VehicleType', 'make', 'Model', 'bodytype', 'VehicleIntroDate', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder']

# %%
# 1. Check for fully duplicated rows
duplicate_rows = df[df.duplicated()]
print(f"Fully duplicated rows: {duplicate_rows.shape[0]}")
# Out:
# Fully duplicated rows: 0

# %%
# Define placeholder strings often used to mean "missing"
empty_like_values = ['', ' ', 'nan', 'NaN', 'NULL', '-', '.', 'N/A']

# Count suspiciously empty-looking entries in each column
suspicious_counts = {}

for col in df.columns:
    if df[col].dtype == object or pd.api.types.is_string_dtype(df[col]):
        # Convert to string, strip whitespace, and check if value is in placeholder list
        count = df[col].astype(str).str.strip().isin(empty_like_values).sum()
        if count > 0:
            suspicious_counts[col] = count

# Display all columns with suspicious values
suspicious_df = pd.DataFrame(list(suspicious_counts.items()), columns=['Column', 'SuspiciousEmptyCount'])
suspicious_df = suspicious_df.sort_values(by='SuspiciousEmptyCount', ascending=False)

print(suspicious_df)
# Out:
#                 Column  SuspiciousEmptyCount
# 15         CrossBorder                999400
# 0          Citizenship                895210
# 14           Converted                641901
# 12          WrittenOff                641901
# 13             Rebuilt                641901
# 11          NewVehicle                153295
# 1                 Bank                145961
# 2          AccountType                 40232
# 4               Gender                  9536
# 3        MaritalStatus                  8259
# 5          VehicleType                   552
# 6                 make                   552
# 7                Model                   552
# 8             bodytype                   552
# 9     VehicleIntroDate                   552
# 10  CapitalOutstanding                     2

# %% [markdown]
# """ 1. CrossBorder
# - Indicates whether a vehicle or policyholder has been involved in cross-border activities (e.g., import/export, usage across countries).
#
# Insurance Value:
#
#  — Can be important for fraud detection, risk assessment, or regulatory compliance.
#
# However — If it's ~99.94% missing, it may not be reliably useful unless i can recover that data from another source.
#
# Verdict:  High value in theory, but with 99.9% missing, likely unusable.
#
#  2. Citizenship
# - Likely the citizenship status of the customer.
#
# Insurance Value:
#
# Useful for KYC (Know Your Customer), risk scoring, or eligibility (e.g., certain citizenships may have different coverage rules).
#
# Can also correlate with fraud checks, travel patterns, or international claims.
#
# Verdict:  Potentially valuable for regulatory and risk purposes. But with ~89% missing, it's limited in its utility unless cleaned or enhanced.
#
#  3. Converted
# - Might indicate whether a quote or lead was converted to a policy or converted vehicle type (e.g., modified car).
#
# Insurance Value:
#
# If it's about sales conversion: very useful for sales funnel analysis.
#
# If it's about vehicle modification: important for underwriting and pricing risk.
#
# Verdict:  Useful, depending on exact meaning. But 64% missing — keep only if meaning is confirmed and missingness is explainable.
#
#  4. WrittenOff
# --  Indicates if the vehicle was declared a total loss (“written off”) after damage.
#
# Insurance Value:
#
# Very important for claims history and underwriting.
#
# Vehicles previously written off may be ineligible or have special terms.
#
# Useful for fraud detection if someone tries to insure already written-off vehicles.
#
# -  High business value for underwriting and claims analysis — worth cleaning or sourcing better.
#
#  5. Rebuilt
# - Indicates if a vehicle was rebuilt after being written off (common in salvage or refurbished vehicle cases).
#
# Insurance Value:
#
# Critical for vehicle valuation and coverage terms.
#
# Rebuilt vehicles often require special handling or premiums.
#
# Verdict:  Important for pricing and risk — may justify effort to recover or clean data."""

# %%
#lets drop high empty columns 
cols_to_drop = ['CrossBorder', 'Citizenship']
df.drop(columns=cols_to_drop, inplace=True)
print("Dropped columns:", cols_to_drop)
# Check remaining columns after dropping
print("Remaining columns after drop:", df.columns.tolist())
# Out:
# Dropped columns: ['CrossBorder', 'Citizenship']
# Remaining columns after drop: ['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth', 'IsVATRegistered', 'LegalType', 'Title', 'Language', 'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province', 'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode', 'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders', 'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors', 'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser', 'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'NumberOfVehiclesInFleet', 'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm', 'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium', 'TotalClaims']

# %%
#retian risk flag for converted, writen off, rebuilt,
#imputing missing vlaues as "unknown"
for col in ['Converted', 'WrittenOff', 'Rebuilt']:
    df[col] = df[col].fillna('Unknown')  # or False
print("Imputed missing values for risk flags:", ['Converted', 'WrittenOff', 'Rebuilt'])
# Check if any of these columns still have missing values
print("Missing values after imputation:")
print(df[['Converted', 'WrittenOff', 'Rebuilt']].isnull().sum())
# Out:
# Imputed missing values for risk flags: ['Converted', 'WrittenOff', 'Rebuilt']
# Missing values after imputation:
# Converted     0
# WrittenOff    0
# Rebuilt       0
# dtype: int64

# %%
df.head(10)
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
# 5               145247     12827  2015-01-01 00:00:00             True
# 6               145247     12827  2015-04-01 00:00:00             True
# 7               145247     12827  2015-06-01 00:00:00             True
# 8               145247     12827  2015-08-01 00:00:00             True
# 9               145245     12827  2015-03-01 00:00:00             True
#
#            LegalType Title Language                 Bank      AccountType  \
# 0  Close Corporation    Mr  English  First National Bank  Current account
# 1  Close Corporation    Mr  English  First National Bank  Current account
# 2  Close Corporation    Mr  English  First National Bank  Current account
# 3  Close Corporation    Mr  English  First National Bank  Current account
# 4  Close Corporation    Mr  English  First National Bank  Current account
# 5  Close Corporation    Mr  English  First National Bank  Current account
# 6  Close Corporation    Mr  English  First National Bank  Current account
# 7  Close Corporation    Mr  English  First National Bank  Current account
# 8  Close Corporation    Mr  English  First National Bank  Current account
# 9  Close Corporation    Mr  English  First National Bank  Current account
#
#    MaritalStatus         Gender       Country Province  PostalCode  \
# 0  Not specified  Not specified  South Africa  Gauteng        1459
# 1  Not specified  Not specified  South Africa  Gauteng        1459
# 2  Not specified  Not specified  South Africa  Gauteng        1459
# 3  Not specified  Not specified  South Africa  Gauteng        1459
# 4  Not specified  Not specified  South Africa  Gauteng        1459
# 5  Not specified  Not specified  South Africa  Gauteng        1459
# 6  Not specified  Not specified  South Africa  Gauteng        1459
# 7  Not specified  Not specified  South Africa  Gauteng        1459
# 8  Not specified  Not specified  South Africa  Gauteng        1459
# 9  Not specified  Not specified  South Africa  Gauteng        1459
#
#   MainCrestaZone SubCrestaZone          ItemType      mmcode  \
# 0      Rand East     Rand East  Mobility - Motor  44069150.0
# 1      Rand East     Rand East  Mobility - Motor  44069150.0
# 2      Rand East     Rand East  Mobility - Motor  44069150.0
# 3      Rand East     Rand East  Mobility - Motor  44069150.0
# 4      Rand East     Rand East  Mobility - Motor  44069150.0
# 5      Rand East     Rand East  Mobility - Motor  44069150.0
# 6      Rand East     Rand East  Mobility - Motor  44069150.0
# 7      Rand East     Rand East  Mobility - Motor  44069150.0
# 8      Rand East     Rand East  Mobility - Motor  44069150.0
# 9      Rand East     Rand East  Mobility - Motor  44069150.0
#
#          VehicleType  RegistrationYear           make  Model  Cylinders  \
# 0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 1  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 2  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 3  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 4  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 5  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 6  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 7  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 8  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 9  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
#
#    cubiccapacity  kilowatts bodytype  NumberOfDoors VehicleIntroDate  \
# 0         2597.0      130.0      S/D            4.0           6/2002
# 1         2597.0      130.0      S/D            4.0           6/2002
# 2         2597.0      130.0      S/D            4.0           6/2002
# 3         2597.0      130.0      S/D            4.0           6/2002
# 4         2597.0      130.0      S/D            4.0           6/2002
# 5         2597.0      130.0      S/D            4.0           6/2002
# 6         2597.0      130.0      S/D            4.0           6/2002
# 7         2597.0      130.0      S/D            4.0           6/2002
# 8         2597.0      130.0      S/D            4.0           6/2002
# 9         2597.0      130.0      S/D            4.0           6/2002
#
#    CustomValueEstimate AlarmImmobiliser TrackingDevice CapitalOutstanding  \
# 0             119300.0              Yes             No             119300
# 1             119300.0              Yes             No             119300
# 2             119300.0              Yes             No             119300
# 3             119300.0              Yes             No             119300
# 4             119300.0              Yes             No             119300
# 5             119300.0              Yes             No             119300
# 6             119300.0              Yes             No             119300
# 7             119300.0              Yes             No             119300
# 8             119300.0              Yes             No             119300
# 9             119300.0              Yes             No             119300
#
#            NewVehicle WrittenOff  Rebuilt Converted  NumberOfVehiclesInFleet  \
# 0  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 1  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 2  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 3  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 4  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 5  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 6  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 7  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 8  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 9  More than 6 months    Unknown  Unknown   Unknown                      NaN
#
#    SumInsured TermFrequency  CalculatedPremiumPerTerm  \
# 0        0.01       Monthly                   25.0000
# 1        0.01       Monthly                   25.0000
# 2        0.01       Monthly                   25.0000
# 3   119300.00       Monthly                  584.6468
# 4   119300.00       Monthly                  584.6468
# 5   500000.00       Monthly                   57.5412
# 6   500000.00       Monthly                   57.5412
# 7   500000.00       Monthly                   57.5412
# 8   500000.00       Monthly                   57.5412
# 9  5000000.00       Monthly                    1.1508
#
#                      ExcessSelected        CoverCategory            CoverType  \
# 0             Mobility - Windscreen           Windscreen           Windscreen
# 1             Mobility - Windscreen           Windscreen           Windscreen
# 2             Mobility - Windscreen           Windscreen           Windscreen
# 3  Mobility - Metered Taxis - R2000           Own damage           Own Damage
# 4  Mobility - Metered Taxis - R2000           Own damage           Own Damage
# 5                         No excess          Third Party          Third Party
# 6                         No excess          Third Party          Third Party
# 7                         No excess          Third Party          Third Party
# 8                         No excess          Third Party          Third Party
# 9                         No excess  Passenger Liability  Passenger Liability
#
#              CoverGroup              Section                          Product  \
# 0  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 1  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 2  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 3  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 4  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 5  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 6  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 7  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 8  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 9  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
#
#   StatutoryClass StatutoryRiskType  TotalPremium  TotalClaims
# 0     Commercial     IFRS Constant     21.929825          0.0
# 1     Commercial     IFRS Constant     21.929825          0.0
# 2     Commercial     IFRS Constant      0.000000          0.0
# 3     Commercial     IFRS Constant    512.848070          0.0
# 4     Commercial     IFRS Constant      0.000000          0.0
# 5     Commercial     IFRS Constant      3.256435          0.0
# 6     Commercial     IFRS Constant     50.474737          0.0
# 7     Commercial     IFRS Constant     35.332316          0.0
# 8     Commercial     IFRS Constant      0.000000          0.0
# 9     Commercial     IFRS Constant      1.009474          0.0

# %%
# group or impute moderate missing columns
# for columns like bank, account type, gender, matital status
df['Bank'] = df['Bank'].fillna('Unknown')
df['Gender'] = df['Gender'].fillna('Unknown')
df['MaritalStatus'] = df['MaritalStatus'].fillna('Unknown')
df['AccountType'] = df['AccountType'].fillna('Unknown')

# %%
df.head(10)
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
# 5               145247     12827  2015-01-01 00:00:00             True
# 6               145247     12827  2015-04-01 00:00:00             True
# 7               145247     12827  2015-06-01 00:00:00             True
# 8               145247     12827  2015-08-01 00:00:00             True
# 9               145245     12827  2015-03-01 00:00:00             True
#
#            LegalType Title Language                 Bank      AccountType  \
# 0  Close Corporation    Mr  English  First National Bank  Current account
# 1  Close Corporation    Mr  English  First National Bank  Current account
# 2  Close Corporation    Mr  English  First National Bank  Current account
# 3  Close Corporation    Mr  English  First National Bank  Current account
# 4  Close Corporation    Mr  English  First National Bank  Current account
# 5  Close Corporation    Mr  English  First National Bank  Current account
# 6  Close Corporation    Mr  English  First National Bank  Current account
# 7  Close Corporation    Mr  English  First National Bank  Current account
# 8  Close Corporation    Mr  English  First National Bank  Current account
# 9  Close Corporation    Mr  English  First National Bank  Current account
#
#    MaritalStatus         Gender       Country Province  PostalCode  \
# 0  Not specified  Not specified  South Africa  Gauteng        1459
# 1  Not specified  Not specified  South Africa  Gauteng        1459
# 2  Not specified  Not specified  South Africa  Gauteng        1459
# 3  Not specified  Not specified  South Africa  Gauteng        1459
# 4  Not specified  Not specified  South Africa  Gauteng        1459
# 5  Not specified  Not specified  South Africa  Gauteng        1459
# 6  Not specified  Not specified  South Africa  Gauteng        1459
# 7  Not specified  Not specified  South Africa  Gauteng        1459
# 8  Not specified  Not specified  South Africa  Gauteng        1459
# 9  Not specified  Not specified  South Africa  Gauteng        1459
#
#   MainCrestaZone SubCrestaZone          ItemType      mmcode  \
# 0      Rand East     Rand East  Mobility - Motor  44069150.0
# 1      Rand East     Rand East  Mobility - Motor  44069150.0
# 2      Rand East     Rand East  Mobility - Motor  44069150.0
# 3      Rand East     Rand East  Mobility - Motor  44069150.0
# 4      Rand East     Rand East  Mobility - Motor  44069150.0
# 5      Rand East     Rand East  Mobility - Motor  44069150.0
# 6      Rand East     Rand East  Mobility - Motor  44069150.0
# 7      Rand East     Rand East  Mobility - Motor  44069150.0
# 8      Rand East     Rand East  Mobility - Motor  44069150.0
# 9      Rand East     Rand East  Mobility - Motor  44069150.0
#
#          VehicleType  RegistrationYear           make  Model  Cylinders  \
# 0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 1  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 2  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 3  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 4  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 5  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 6  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 7  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 8  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 9  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
#
#    cubiccapacity  kilowatts bodytype  NumberOfDoors VehicleIntroDate  \
# 0         2597.0      130.0      S/D            4.0           6/2002
# 1         2597.0      130.0      S/D            4.0           6/2002
# 2         2597.0      130.0      S/D            4.0           6/2002
# 3         2597.0      130.0      S/D            4.0           6/2002
# 4         2597.0      130.0      S/D            4.0           6/2002
# 5         2597.0      130.0      S/D            4.0           6/2002
# 6         2597.0      130.0      S/D            4.0           6/2002
# 7         2597.0      130.0      S/D            4.0           6/2002
# 8         2597.0      130.0      S/D            4.0           6/2002
# 9         2597.0      130.0      S/D            4.0           6/2002
#
#    CustomValueEstimate AlarmImmobiliser TrackingDevice CapitalOutstanding  \
# 0             119300.0              Yes             No             119300
# 1             119300.0              Yes             No             119300
# 2             119300.0              Yes             No             119300
# 3             119300.0              Yes             No             119300
# 4             119300.0              Yes             No             119300
# 5             119300.0              Yes             No             119300
# 6             119300.0              Yes             No             119300
# 7             119300.0              Yes             No             119300
# 8             119300.0              Yes             No             119300
# 9             119300.0              Yes             No             119300
#
#            NewVehicle WrittenOff  Rebuilt Converted  NumberOfVehiclesInFleet  \
# 0  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 1  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 2  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 3  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 4  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 5  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 6  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 7  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 8  More than 6 months    Unknown  Unknown   Unknown                      NaN
# 9  More than 6 months    Unknown  Unknown   Unknown                      NaN
#
#    SumInsured TermFrequency  CalculatedPremiumPerTerm  \
# 0        0.01       Monthly                   25.0000
# 1        0.01       Monthly                   25.0000
# 2        0.01       Monthly                   25.0000
# 3   119300.00       Monthly                  584.6468
# 4   119300.00       Monthly                  584.6468
# 5   500000.00       Monthly                   57.5412
# 6   500000.00       Monthly                   57.5412
# 7   500000.00       Monthly                   57.5412
# 8   500000.00       Monthly                   57.5412
# 9  5000000.00       Monthly                    1.1508
#
#                      ExcessSelected        CoverCategory            CoverType  \
# 0             Mobility - Windscreen           Windscreen           Windscreen
# 1             Mobility - Windscreen           Windscreen           Windscreen
# 2             Mobility - Windscreen           Windscreen           Windscreen
# 3  Mobility - Metered Taxis - R2000           Own damage           Own Damage
# 4  Mobility - Metered Taxis - R2000           Own damage           Own Damage
# 5                         No excess          Third Party          Third Party
# 6                         No excess          Third Party          Third Party
# 7                         No excess          Third Party          Third Party
# 8                         No excess          Third Party          Third Party
# 9                         No excess  Passenger Liability  Passenger Liability
#
#              CoverGroup              Section                          Product  \
# 0  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 1  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 2  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 3  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 4  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 5  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 6  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 7  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 8  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 9  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
#
#   StatutoryClass StatutoryRiskType  TotalPremium  TotalClaims
# 0     Commercial     IFRS Constant     21.929825          0.0
# 1     Commercial     IFRS Constant     21.929825          0.0
# 2     Commercial     IFRS Constant      0.000000          0.0
# 3     Commercial     IFRS Constant    512.848070          0.0
# 4     Commercial     IFRS Constant      0.000000          0.0
# 5     Commercial     IFRS Constant      3.256435          0.0
# 6     Commercial     IFRS Constant     50.474737          0.0
# 7     Commercial     IFRS Constant     35.332316          0.0
# 8     Commercial     IFRS Constant      0.000000          0.0
# 9     Commercial     IFRS Constant      1.009474          0.0

# %%
#fix minor missing columns for vihicles type, make, model , bodytype and vehicle introdate
df.dropna(subset=['VehicleType', 'make', 'Model','VehicleIntroDate','bodytype','CapitalOutstanding'], inplace=True)
# Check if any of these columns still have missing values
print("Missing values after dropping rows with minor missing columns:")
print(df[['VehicleType', 'make', 'Model', 'VehicleIntroDate', 'bodytype','CapitalOutstanding']].isnull().sum())
# Out:
# Missing values after dropping rows with minor missing columns:
# VehicleType           0
# make                  0
# Model                 0
# VehicleIntroDate      0
# bodytype              0
# CapitalOutstanding    0
# dtype: int64

# %%
# now lets check any missing values in any columns 
missing_summary = df.isnull().sum().sort_values(ascending=False)
missing_pct = (missing_summary / len(df)) * 100
missing_df = pd.DataFrame({
    'missing_count': missing_summary,
    'missing_percent': missing_pct
})
print("Final missing values summary:")
print(missing_df[missing_df.missing_count > 0].head(10))  # Top missing columns after cleaning
# Out:
# Final missing values summary:
#                          missing_count  missing_percent
# NumberOfVehiclesInFleet         999544       100.000000
# CustomValueEstimate             779088        77.944343
# NewVehicle                      153295        15.336493

# %%
#drope customeValueE    stimate as it has 787% missing values
df.drop(columns=['CustomValueEstimate'], inplace=True)
print("Dropped column: CustomValueEstimate due to high missing values.")
# drop numberof vehicles as it has 100% missing values
df.drop(columns=['NumberOfVehiclesInFleet'], inplace=True)
print("Dropped column: NumberOfVehiclesInFleet due to 100% missing values.")
# Out:
# Dropped column: CustomValueEstimate due to high missing values.
# Dropped column: NumberOfVehiclesInFleet due to 100% missing values.

# %%
# Fill missing NewVehicle values with 'Unknown'
df['NewVehicle'] = df['NewVehicle'].fillna('Unknown')
# Check if any of these columns still have missing values
print("Missing values after filling NewVehicle:")
print(df['NewVehicle'].isnull().sum())
# Check for any remaining missing values
print("Final missing values summary after all cleaning:")
missing_summary = df.isnull().sum().sort_values(ascending=False)
missing_pct = (missing_summary / len(df)) * 100
missing_df = pd.DataFrame({
    'missing_count': missing_summary,
    'missing_percent': missing_pct
})
print(missing_df[missing_df.missing_count > 0].head(10))  # Top missing columns after all cleaning
# Out:
# Missing values after filling NewVehicle:
# 0
# Final missing values summary after all cleaning:
# Empty DataFrame
# Columns: [missing_count, missing_percent]
# Index: []

# %%
# Check remaining columns after dropping
print("Remaining columns after final drop:", df.columns.tolist())
# Out:
# Remaining columns after final drop: ['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth', 'IsVATRegistered', 'LegalType', 'Title', 'Language', 'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province', 'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode', 'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders', 'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors', 'VehicleIntroDate', 'AlarmImmobiliser', 'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm', 'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium', 'TotalClaims']

# %%
# now lets check data types
# Check data types of all columns
print("Data types of all columns:")
df.dtypes.sort_values()
# Out:
# Data types of all columns:
# IsVATRegistered                bool
# UnderwrittenCoverID           int64
# PolicyID                      int64
# RegistrationYear              int64
# PostalCode                    int64
# CalculatedPremiumPerTerm    float64
# SumInsured                  float64
# NumberOfDoors               float64
# kilowatts                   float64
# TotalPremium                float64
# Cylinders                   float64
# mmcode                      float64
# cubiccapacity               float64
# TotalClaims                 float64
# WrittenOff                   object
# Rebuilt                      object
# Converted                    object
# LegalType                    object
# TermFrequency                object
# TransactionMonth             object
# NewVehicle                   object
# ExcessSelected               object
# CoverType                    object
# CoverGroup                   object
# Section                      object
# Product                      object
# StatutoryClass               object
# StatutoryRiskType            object
# CoverCategory                object
# Province                     object
# Country                      object
# AlarmImmobiliser             object
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# Gender                       object
# VehicleType                  object
# MaritalStatus                object
# TrackingDevice               object
# make                         object
# AccountType                  object
# Bank                         object
# Language                     object
# bodytype                     object
# Title                        object
# VehicleIntroDate             object
# Model                        object
# CapitalOutstanding           object
# dtype: object

# %% [markdown]
# | Column               | Problem                         | Expected Type    | Reason/Fix                              |
# | -------------------- | ------------------------------- | ---------------- | --------------------------------------- |
# | `TransactionMonth`   |  is `object` (string)          | `datetime64[ns]` | Time-based analysis, sorting, filtering |
# | `VehicleIntroDate`   |  is `object`                   | `datetime64[ns]` | Needed to compute vehicle age, trends   |
# | `NewVehicle`         |  is `object`                   | `bool`           | Logical column (Yes/No)                 |
# | `WrittenOff`         |  is `object`                   | `bool`           | Logical flag                            |
# | `Rebuilt`            |  is `object`                   | `bool`           | Logical flag                            |
# | `Converted`          |  is `object`                   | `bool`           | Logical flag                            |
# | `CapitalOutstanding` |  is `object` (should be float) | `float64`        | Financial amount                        |

# %% [markdown]
# """Already Correct:
# Booleans: IsVATRegistered
#
# Numerical: All key numeric columns like TotalPremium, SumInsured, etc. are correctly float64
#
# Identifiers: PolicyID, UnderwrittenCoverID are int64 """

# %%
#fix dates
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'], errors='coerce')
df['VehicleIntroDate'] = pd.to_datetime(df['VehicleIntroDate'], errors='coerce')

# Check again
print(df[['TransactionMonth', 'VehicleIntroDate']].dtypes)
# Out:
# TransactionMonth    datetime64[ns]
# VehicleIntroDate    datetime64[ns]
# dtype: object
# /tmp/ipykernel_56564/542130726.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['VehicleIntroDate'] = pd.to_datetime(df['VehicleIntroDate'], errors='coerce')

# %%
#lets convert binary columns to boolean
binary_cols = ['NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted']

for col in binary_cols:
    df[col] = df[col].astype(str).str.strip().str.lower()
    df[col] = df[col].replace({'yes': True, 'no': False, 'unknown': False, '': False, 'nan': False})
    df[col] = df[col].replace('nan', False).fillna(False)
    df[col] = df[col].astype(bool)

print("Data types after conversion:")
print(df[binary_cols].dtypes)
# Out:
# /tmp/ipykernel_56564/232422190.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace({'yes': True, 'no': False, 'unknown': False, '': False, 'nan': False})
# /tmp/ipykernel_56564/232422190.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace({'yes': True, 'no': False, 'unknown': False, '': False, 'nan': False})
# Data types after conversion:
# NewVehicle    bool
# WrittenOff    bool
# Rebuilt       bool
# Converted     bool
# dtype: object
# /tmp/ipykernel_56564/232422190.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace({'yes': True, 'no': False, 'unknown': False, '': False, 'nan': False})

# %%
# capital outstanding should be float
df['CapitalOutstanding'] = (
    df['CapitalOutstanding']
    .astype(str)
    .str.replace(',', '')
    .str.extract(r'(\d+\.?\d*)')[0]  # Extract just the number part
)

df['CapitalOutstanding'] = pd.to_numeric(df['CapitalOutstanding'], errors='coerce')
# Check if conversion was successful
print("Data types after converting CapitalOutstanding:")
print(df['CapitalOutstanding'].dtype)
# Check final data types
print("Final data types of all columns:")
print(df.dtypes.sort_values())
# Out:
# Data types after converting CapitalOutstanding:
# float64
# Final data types of all columns:
# NewVehicle                            bool
# PostalCode                           int64
# VehicleIntroDate            datetime64[ns]
# IsVATRegistered                       bool
# WrittenOff                            bool
# Converted                             bool
# Rebuilt                               bool
# UnderwrittenCoverID                  int64
# PolicyID                             int64
# RegistrationYear                     int64
# Cylinders                          float64
# CapitalOutstanding                 float64
# CalculatedPremiumPerTerm           float64
# NumberOfDoors                      float64
# kilowatts                          float64
# TotalPremium                       float64
# SumInsured                         float64
# cubiccapacity                      float64
# TotalClaims                        float64
# TransactionMonth            datetime64[ns]
# mmcode                             float64
# StatutoryRiskType                   object
# StatutoryClass                      object
# Product                             object
# Section                             object
# CoverGroup                          object
# CoverType                           object
# CoverCategory                       object
# ExcessSelected                      object
# TermFrequency                       object
# LegalType                           object
# Title                               object
# Language                            object
# VehicleType                         object
# MaritalStatus                       object
# TrackingDevice                      object
# AlarmImmobiliser                    object
# Gender                              object
# Country                             object
# bodytype                            object
# Province                            object
# MainCrestaZone                      object
# SubCrestaZone                       object
# Model                               object
# make                                object
# ItemType                            object
# AccountType                         object
# Bank                                object
# dtype: object

# %%
df.shape
# Out:
# (999544, 48)

# %%
# since we dont have unique id for all rows 
df['RecordID'] = df.index
print(df.shape)  # Should print (1000098, 53)
# Out:
# (999544, 49)

# %%
#check if record is unique
# so i have give just record id column that uniquly idntifies each raws
assert df['RecordID'].is_unique

# %%
#lets put upfront the record id column
cols = ['RecordID'] + [col for col in df.columns if col != 'RecordID']
df = df[cols]

# %%
df.head(10)
# Out:
#    RecordID  UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0         0               145249     12827       2015-03-01             True
# 1         1               145249     12827       2015-05-01             True
# 2         2               145249     12827       2015-07-01             True
# 3         3               145255     12827       2015-05-01             True
# 4         4               145255     12827       2015-07-01             True
# 5         5               145247     12827       2015-01-01             True
# 6         6               145247     12827       2015-04-01             True
# 7         7               145247     12827       2015-06-01             True
# 8         8               145247     12827       2015-08-01             True
# 9         9               145245     12827       2015-03-01             True
#
#            LegalType Title Language                 Bank      AccountType  \
# 0  Close Corporation    Mr  English  First National Bank  Current account
# 1  Close Corporation    Mr  English  First National Bank  Current account
# 2  Close Corporation    Mr  English  First National Bank  Current account
# 3  Close Corporation    Mr  English  First National Bank  Current account
# 4  Close Corporation    Mr  English  First National Bank  Current account
# 5  Close Corporation    Mr  English  First National Bank  Current account
# 6  Close Corporation    Mr  English  First National Bank  Current account
# 7  Close Corporation    Mr  English  First National Bank  Current account
# 8  Close Corporation    Mr  English  First National Bank  Current account
# 9  Close Corporation    Mr  English  First National Bank  Current account
#
#    MaritalStatus         Gender       Country Province  PostalCode  \
# 0  Not specified  Not specified  South Africa  Gauteng        1459
# 1  Not specified  Not specified  South Africa  Gauteng        1459
# 2  Not specified  Not specified  South Africa  Gauteng        1459
# 3  Not specified  Not specified  South Africa  Gauteng        1459
# 4  Not specified  Not specified  South Africa  Gauteng        1459
# 5  Not specified  Not specified  South Africa  Gauteng        1459
# 6  Not specified  Not specified  South Africa  Gauteng        1459
# 7  Not specified  Not specified  South Africa  Gauteng        1459
# 8  Not specified  Not specified  South Africa  Gauteng        1459
# 9  Not specified  Not specified  South Africa  Gauteng        1459
#
#   MainCrestaZone SubCrestaZone          ItemType      mmcode  \
# 0      Rand East     Rand East  Mobility - Motor  44069150.0
# 1      Rand East     Rand East  Mobility - Motor  44069150.0
# 2      Rand East     Rand East  Mobility - Motor  44069150.0
# 3      Rand East     Rand East  Mobility - Motor  44069150.0
# 4      Rand East     Rand East  Mobility - Motor  44069150.0
# 5      Rand East     Rand East  Mobility - Motor  44069150.0
# 6      Rand East     Rand East  Mobility - Motor  44069150.0
# 7      Rand East     Rand East  Mobility - Motor  44069150.0
# 8      Rand East     Rand East  Mobility - Motor  44069150.0
# 9      Rand East     Rand East  Mobility - Motor  44069150.0
#
#          VehicleType  RegistrationYear           make  Model  Cylinders  \
# 0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 1  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 2  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 3  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 4  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 5  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 6  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 7  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 8  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 9  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
#
#    cubiccapacity  kilowatts bodytype  NumberOfDoors VehicleIntroDate  \
# 0         2597.0      130.0      S/D            4.0       2002-06-01
# 1         2597.0      130.0      S/D            4.0       2002-06-01
# 2         2597.0      130.0      S/D            4.0       2002-06-01
# 3         2597.0      130.0      S/D            4.0       2002-06-01
# 4         2597.0      130.0      S/D            4.0       2002-06-01
# 5         2597.0      130.0      S/D            4.0       2002-06-01
# 6         2597.0      130.0      S/D            4.0       2002-06-01
# 7         2597.0      130.0      S/D            4.0       2002-06-01
# 8         2597.0      130.0      S/D            4.0       2002-06-01
# 9         2597.0      130.0      S/D            4.0       2002-06-01
#
#   AlarmImmobiliser TrackingDevice  CapitalOutstanding  NewVehicle  WrittenOff  \
# 0              Yes             No            119300.0        True       False
# 1              Yes             No            119300.0        True       False
# 2              Yes             No            119300.0        True       False
# 3              Yes             No            119300.0        True       False
# 4              Yes             No            119300.0        True       False
# 5              Yes             No            119300.0        True       False
# 6              Yes             No            119300.0        True       False
# 7              Yes             No            119300.0        True       False
# 8              Yes             No            119300.0        True       False
# 9              Yes             No            119300.0        True       False
#
#    Rebuilt  Converted  SumInsured TermFrequency  CalculatedPremiumPerTerm  \
# 0    False      False        0.01       Monthly                   25.0000
# 1    False      False        0.01       Monthly                   25.0000
# 2    False      False        0.01       Monthly                   25.0000
# 3    False      False   119300.00       Monthly                  584.6468
# 4    False      False   119300.00       Monthly                  584.6468
# 5    False      False   500000.00       Monthly                   57.5412
# 6    False      False   500000.00       Monthly                   57.5412
# 7    False      False   500000.00       Monthly                   57.5412
# 8    False      False   500000.00       Monthly                   57.5412
# 9    False      False  5000000.00       Monthly                    1.1508
#
#                      ExcessSelected        CoverCategory            CoverType  \
# 0             Mobility - Windscreen           Windscreen           Windscreen
# 1             Mobility - Windscreen           Windscreen           Windscreen
# 2             Mobility - Windscreen           Windscreen           Windscreen
# 3  Mobility - Metered Taxis - R2000           Own damage           Own Damage
# 4  Mobility - Metered Taxis - R2000           Own damage           Own Damage
# 5                         No excess          Third Party          Third Party
# 6                         No excess          Third Party          Third Party
# 7                         No excess          Third Party          Third Party
# 8                         No excess          Third Party          Third Party
# 9                         No excess  Passenger Liability  Passenger Liability
#
#              CoverGroup              Section                          Product  \
# 0  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 1  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 2  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 3  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 4  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 5  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 6  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 7  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 8  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 9  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
#
#   StatutoryClass StatutoryRiskType  TotalPremium  TotalClaims
# 0     Commercial     IFRS Constant     21.929825          0.0
# 1     Commercial     IFRS Constant     21.929825          0.0
# 2     Commercial     IFRS Constant      0.000000          0.0
# 3     Commercial     IFRS Constant    512.848070          0.0
# 4     Commercial     IFRS Constant      0.000000          0.0
# 5     Commercial     IFRS Constant      3.256435          0.0
# 6     Commercial     IFRS Constant     50.474737          0.0
# 7     Commercial     IFRS Constant     35.332316          0.0
# 8     Commercial     IFRS Constant      0.000000          0.0
# 9     Commercial     IFRS Constant      1.009474          0.0

# %%
# Set pandas option to display all columns
pd.set_option('display.max_columns', None)

# Now display your DataFrame head to see all columns
print(df.head())
# Out:
#    RecordID  UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0         0               145249     12827       2015-03-01             True
# 1         1               145249     12827       2015-05-01             True
# 2         2               145249     12827       2015-07-01             True
# 3         3               145255     12827       2015-05-01             True
# 4         4               145255     12827       2015-07-01             True
#
#            LegalType Title Language                 Bank      AccountType  \
# 0  Close Corporation    Mr  English  First National Bank  Current account
# 1  Close Corporation    Mr  English  First National Bank  Current account
# 2  Close Corporation    Mr  English  First National Bank  Current account
# 3  Close Corporation    Mr  English  First National Bank  Current account
# 4  Close Corporation    Mr  English  First National Bank  Current account
#
#    MaritalStatus         Gender       Country Province  PostalCode  \
# 0  Not specified  Not specified  South Africa  Gauteng        1459
# 1  Not specified  Not specified  South Africa  Gauteng        1459
# 2  Not specified  Not specified  South Africa  Gauteng        1459
# 3  Not specified  Not specified  South Africa  Gauteng        1459
# 4  Not specified  Not specified  South Africa  Gauteng        1459
#
#   MainCrestaZone SubCrestaZone          ItemType      mmcode  \
# 0      Rand East     Rand East  Mobility - Motor  44069150.0
# 1      Rand East     Rand East  Mobility - Motor  44069150.0
# 2      Rand East     Rand East  Mobility - Motor  44069150.0
# 3      Rand East     Rand East  Mobility - Motor  44069150.0
# 4      Rand East     Rand East  Mobility - Motor  44069150.0
#
#          VehicleType  RegistrationYear           make  Model  Cylinders  \
# 0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 1  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 2  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 3  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 4  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
#
#    cubiccapacity  kilowatts bodytype  NumberOfDoors VehicleIntroDate  \
# 0         2597.0      130.0      S/D            4.0       2002-06-01
# 1         2597.0      130.0      S/D            4.0       2002-06-01
# 2         2597.0      130.0      S/D            4.0       2002-06-01
# 3         2597.0      130.0      S/D            4.0       2002-06-01
# 4         2597.0      130.0      S/D            4.0       2002-06-01
#
#   AlarmImmobiliser TrackingDevice  CapitalOutstanding  NewVehicle  WrittenOff  \
# 0              Yes             No            119300.0        True       False
# 1              Yes             No            119300.0        True       False
# 2              Yes             No            119300.0        True       False
# 3              Yes             No            119300.0        True       False
# 4              Yes             No            119300.0        True       False
#
#    Rebuilt  Converted  SumInsured TermFrequency  CalculatedPremiumPerTerm  \
# 0    False      False        0.01       Monthly                   25.0000
# 1    False      False        0.01       Monthly                   25.0000
# 2    False      False        0.01       Monthly                   25.0000
# 3    False      False   119300.00       Monthly                  584.6468
# 4    False      False   119300.00       Monthly                  584.6468
#
#                      ExcessSelected CoverCategory   CoverType  \
# 0             Mobility - Windscreen    Windscreen  Windscreen
# 1             Mobility - Windscreen    Windscreen  Windscreen
# 2             Mobility - Windscreen    Windscreen  Windscreen
# 3  Mobility - Metered Taxis - R2000    Own damage  Own Damage
# 4  Mobility - Metered Taxis - R2000    Own damage  Own Damage
#
#              CoverGroup              Section                          Product  \
# 0  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 1  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 2  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 3  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 4  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
#
#   StatutoryClass StatutoryRiskType  TotalPremium  TotalClaims
# 0     Commercial     IFRS Constant     21.929825          0.0
# 1     Commercial     IFRS Constant     21.929825          0.0
# 2     Commercial     IFRS Constant      0.000000          0.0
# 3     Commercial     IFRS Constant    512.848070          0.0
# 4     Commercial     IFRS Constant      0.000000          0.0

# %%
# define catagorical columns to check
cat_cols = [
    'Gender', 'MaritalStatus', 'Province', 'VehicleType', 'Title',
    'CoverType', 'CoverCategory', 'NewVehicle', 'WrittenOff', 'Rebuilt',
    'Converted', 'Bank', 'AccountType', 'Language'
]

# %%
# lets view unique values in categorical columns
for col in cat_cols:
    print(f"\n {col} ")
    print(df[col].value_counts(dropna=False))
# Out:
#  Gender
# Gender
# Not specified    940436
# Male              42817
# Unknown            9536
# Female             6755
# Name: count, dtype: int64
#
#  MaritalStatus
# MaritalStatus
# Not specified    985654
# Unknown            8259
# Single             4254
# Married            1377
# Name: count, dtype: int64
#
#  Province
# Province
# Gauteng          393625
# Western Cape     170562
# KwaZulu-Natal    169781
# North West       143287
# Mpumalanga        52638
# Eastern Cape      30336
# Limpopo           24836
# Free State         8099
# Northern Cape      6380
# Name: count, dtype: int64
#
#  VehicleType
# VehicleType
# Passenger Vehicle    933596
# Medium Commercial     53985
# Heavy Commercial       7401
# Light Commercial       3897
# Bus                     665
# Name: count, dtype: int64
#
#  Title
# Title
# Mr      933002
# Mrs      45849
# Ms       13269
# Miss      6614
# Dr         810
# Name: count, dtype: int64
#
#  CoverType
# CoverType
# Own Damage                                             104120
# Passenger Liability                                    104095
# Windscreen                                             103700
# Third Party                                            102762
# Keys and Alarms                                        102365
# Signage and Vehicle Wraps                              102353
# Emergency Charges                                      102353
# Cleaning and Removal of Accident Debris                102351
# Income Protector                                        64789
# Basic Excess Waiver                                     57745
# Accidental Death                                        27321
# Credit Protection                                       18070
# Roadside Assistance                                      3834
# Deposit Cover                                            1299
# Asset Value Preserver                                     865
# Standalone passenger liability                            542
# Fire and Theft                                            375
# Cash Takings                                              291
# Baggage/Luggage                                           172
# Trailer                                                    76
# Third Party Only                                           63
# Factory Fitted Sound and Other Electronic Equipment         3
# Name: count, dtype: int64
#
#  CoverCategory
# CoverCategory
# Passenger Liability                                    104095
# Third Party                                            102762
# Keys and Alarms                                        102365
# Signage and Vehicle Wraps                              102353
# Emergency Charges                                      102353
# Cleaning and Removal of Accident Debris                102351
# Windscreen                                              97250
# Own Damage                                              78981
# Income Protector                                        59977
# Basic Excess Waiver                                     53731
# Accidental Death                                        27321
# Credit Protection                                       18070
# Own Damage.                                             15061
# Own damage                                               8747
# Windscreen (2015)                                        6450
# Income Protector (2015)                                  4812
# Basic Excess Waiver (2015)                               4014
# Roadside Assistance                                      3834
# Vehicle over R100 000                                    1552
# Deposit Cover                                            1299
# Asset Value Preserver                                     865
# Standalone passenger liability                            542
# Cash Takings                                              291
# Baggage/Luggage                                           172
# Vehicle under R100 000                                    154
# Trailer                                                    76
# Third Party Only                                           63
# Factory Fitted Sound and Other Electronic Equipment         3
# Name: count, dtype: int64
#
#  NewVehicle
# NewVehicle
# True     846249
# False    153295
# Name: count, dtype: int64
#
#  WrittenOff
# WrittenOff
# False    999512
# True         32
# Name: count, dtype: int64
#
#  Rebuilt
# Rebuilt
# False    999512
# True         32
# Name: count, dtype: int64
#
#  Converted
# Converted
# False    999457
# True         87
# Name: count, dtype: int64
#
#  Bank
# Bank
# First National Bank       260811
# ABSA Bank                 204722
# Standard Bank             181475
# Unknown                   145959
# Nedbank                   131923
# Capitec Bank               58155
# RMB Private Bank           12576
# Ithala Bank                 1730
# Investec Bank                732
# Old Mutual                   688
# FirstRand Bank               638
# Mercantile Lisbon Bank       135
# Name: count, dtype: int64
#
#  AccountType
# AccountType
# Current account         597706
# Savings account         357887
# Unknown                  40230
# Transmission account      3721
# Name: count, dtype: int64
#
#  Language
# Language
# English    999544
# Name: count, dtype: int64

# %%
# so based on above output 
"""| Issue                                | Solution                                  |
| ------------------------------------ | ----------------------------------------- |
| Majority is `"Not specified"` (940k) | Normalize `"Not specified"` → `'unknown'` |
| Mixed casing (`Male`, `Female`)      | Convert to lowercase                      |

"""
df['Gender'] = df['Gender'].str.strip().str.lower().replace({
    'not specified': 'unknown',
    '': 'unknown'
})

# same for marital status
df['MaritalStatus'] = df['MaritalStatus'].str.strip().str.lower().replace({
    'not specified': 'unknown',
    '': 'unknown'
})

# %%
# province
#vehicle type both no need change 
# for title lets chenge to lower case all

""" Title
Titles are clean (Mr, Mrs, etc.)
 Optional: Normalize to lowercase:"""

df['Title'] = df['Title'].str.strip().str.lower()\
# cover type is clean

# %%
""" 
CoverCategory

Needs cleanup:

Variants like "Own damage", "Own Damage.", "Own Damage"

Versions like "Windscreen (2015)", "Income Protector (2015)"

Strategy:

Normalize lowercase

Map noisy variants to clean categories"""

df['CoverCategory'] = df['CoverCategory'].str.strip().str.lower()

# Manual mapping for known noisy duplicates
df['CoverCategory'] = df['CoverCategory'].replace({
    'own damage.': 'own damage',
    'own damage': 'own damage',
    'windscreen (2015)': 'windscreen',
    'income protector (2015)': 'income protector',
    'basic excess waiver (2015)': 'basic excess waiver'
})

"""NewVehicle, WrittenOff, Rebuilt, Converted
Already cleaned — values are Boolean: True/False
No further action needed."""
# Out:
# 'NewVehicle, WrittenOff, Rebuilt, Converted\nAlready cleaned — values are Boolean: True/False\nNo further action needed.'

# %%
"""Bank
Slight variation between banks (FirstRand Bank, First National Bank)"""
# so lets normalize bank names to lowercase and remove extra spaces
# Optional cleanup
df['Bank'] = df['Bank'].str.strip().str.lower().replace({
    'firstrand bank': 'first national bank'
})

# %%
"""AccountType
Mostly clean
Optional: normalize casing & spacing"""
df['AccountType'] = df['AccountType'].str.strip().str.lower()

# %%
"""Language
Uniform — all "English"
Consider dropping it, as it adds no value:"""

df.drop(columns=['Language'], inplace=True)
print("Dropped column: Language as it adds no value.")
# Check remaining columns after cleanup
print("Remaining columns after cleanup:", df.columns.tolist())
# Out:
# Dropped column: Language as it adds no value.
# Remaining columns after cleanup: ['RecordID', 'UnderwrittenCoverID', 'PolicyID', 'TransactionMonth', 'IsVATRegistered', 'LegalType', 'Title', 'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province', 'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode', 'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders', 'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors', 'VehicleIntroDate', 'AlarmImmobiliser', 'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm', 'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium', 'TotalClaims']

# %% [markdown]
# ### outlier detecton and removal

# %%
#basic numeric column description
# checking for min max and un usual values 
df[['TotalPremium', 'TotalClaims', 'SumInsured', 'CalculatedPremiumPerTerm',
    'CapitalOutstanding', 'Cylinders', 'kilowatts', 'cubiccapacity']].describe()
# Out:
#         TotalPremium    TotalClaims    SumInsured  CalculatedPremiumPerTerm  \
# count  999544.000000  999544.000000  9.995440e+05             999544.000000
# mean       61.372350      64.340199  6.038605e+05                116.161425
# std       157.014098    2369.567085  1.507329e+06                220.576166
# min      -782.576754  -12002.412281  1.000000e-02                  0.000000
# 25%         0.000000       0.000000  5.000000e+03                  3.225700
# 50%         2.179737       0.000000  7.500000e+03                  8.436900
# 75%        21.929825       0.000000  2.500000e+05                 90.000000
# max      2253.507281  393092.105263  1.000000e+07               3051.821100
#
#        CapitalOutstanding      Cylinders      kilowatts  cubiccapacity
# count        9.995440e+05  999544.000000  999544.000000  999544.000000
# mean         6.164425e+04       4.046642      97.207964    2466.743461
# std          5.156820e+05       0.294020      19.393250     442.801023
# min          0.000000e+00       0.000000       0.000000       0.000000
# 25%          0.000000e+00       4.000000      75.000000    2237.000000
# 50%          0.000000e+00       4.000000     111.000000    2694.000000
# 75%          0.000000e+00       4.000000     111.000000    2694.000000
# max          2.857000e+07      10.000000     309.000000   12880.000000

# %%
# check for negative or zero premiums 
# as insurance premiums should never be negative or zero 
print("Zero TotalPremium:", (df['TotalPremium'] == 0).sum())
print("Negative TotalPremium:", (df['TotalPremium'] < 0).sum())
# Out:
# Zero TotalPremium: 381302
# Negative TotalPremium: 286

# %%
# sometimes in insurace data, premiums can be zero for certain policies (e.g., free trials, promotional offers)
"""Zero Premiums
These could be:

Waived premiums (e.g., loyalty rewards, free periods)

Transactions like endorsements or policy changes

Data issues (incomplete records)"""
#but
# Negative Premiums
# Negative premiums are likely data errors or misentries
"""Negative Premiums
These are not valid in normal scenarios.

Could mean:

Canceled policies

Refunds

Bad input

Should be removed or flagged.""" 

# lets remove negative premiums
df = df[df['TotalPremium'] >= 0]
print("Removed negative TotalPremium. Remaining rows:", df.shape[0])
# Check again for zero premiums
zero_premiums = (df['TotalPremium'] == 0).sum()
print("Remaining zero TotalPremium:", zero_premiums)
# Out:
# Removed negative TotalPremium. Remaining rows: 999258
# Remaining zero TotalPremium: 381302

# %%
# check for any negative premiums 
#check negative premiums again
negative_premiums = (df['TotalPremium'] < 0).sum()
print("Remaining negative TotalPremium:", negative_premiums)
# Out:
# Remaining negative TotalPremium: 0

# %%
# lets g to claims > premiums ? (loss ratio >1 )
df['LossRatio'] = df['TotalClaims'] / df['TotalPremium']

# Count and inspect
print("Loss Ratio > 1:", (df['LossRatio'] > 1).sum())
print("Max Loss Ratio:", df['LossRatio'].max())
# Out:
# Loss Ratio > 1: 2764
# Max Loss Ratio: inf

# %%
# the output inf max loss ratio mean it is devide by 0 from zero premiums
# so just calculate loss rattio only for non zero values
import numpy as np

# Loss ratio: only when TotalPremium > 0
df['LossRatio'] = np.where(
    df['TotalPremium'] > 0,
    df['TotalClaims'] / df['TotalPremium'],
    np.nan  # Set to NaN when premium is zero
)

# %%
#verify 
print("Loss Ratio null values (should match TotalPremium = 0):", df['LossRatio'].isnull().sum())
print("Any infinite values in Loss Ratio?", np.isinf(df['LossRatio']).sum())
# Out:
# Loss Ratio null values (should match TotalPremium = 0): 381302
# Any infinite values in Loss Ratio? 0

# %%
# drope loss ration column
df.drop(columns=['LossRatio'], inplace=True)
print("Dropped column: LossRatio as it was derived and not needed for further analysis.")
# Out:
# Dropped column: LossRatio as it was derived and not needed for further analysis.

# %%
df.head(10)
# Out:
#    RecordID  UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0         0               145249     12827       2015-03-01             True
# 1         1               145249     12827       2015-05-01             True
# 2         2               145249     12827       2015-07-01             True
# 3         3               145255     12827       2015-05-01             True
# 4         4               145255     12827       2015-07-01             True
# 5         5               145247     12827       2015-01-01             True
# 6         6               145247     12827       2015-04-01             True
# 7         7               145247     12827       2015-06-01             True
# 8         8               145247     12827       2015-08-01             True
# 9         9               145245     12827       2015-03-01             True
#
#            LegalType Title                 Bank      AccountType  \
# 0  Close Corporation    mr  first national bank  current account
# 1  Close Corporation    mr  first national bank  current account
# 2  Close Corporation    mr  first national bank  current account
# 3  Close Corporation    mr  first national bank  current account
# 4  Close Corporation    mr  first national bank  current account
# 5  Close Corporation    mr  first national bank  current account
# 6  Close Corporation    mr  first national bank  current account
# 7  Close Corporation    mr  first national bank  current account
# 8  Close Corporation    mr  first national bank  current account
# 9  Close Corporation    mr  first national bank  current account
#
#   MaritalStatus   Gender       Country Province  PostalCode MainCrestaZone  \
# 0       unknown  unknown  South Africa  Gauteng        1459      Rand East
# 1       unknown  unknown  South Africa  Gauteng        1459      Rand East
# 2       unknown  unknown  South Africa  Gauteng        1459      Rand East
# 3       unknown  unknown  South Africa  Gauteng        1459      Rand East
# 4       unknown  unknown  South Africa  Gauteng        1459      Rand East
# 5       unknown  unknown  South Africa  Gauteng        1459      Rand East
# 6       unknown  unknown  South Africa  Gauteng        1459      Rand East
# 7       unknown  unknown  South Africa  Gauteng        1459      Rand East
# 8       unknown  unknown  South Africa  Gauteng        1459      Rand East
# 9       unknown  unknown  South Africa  Gauteng        1459      Rand East
#
#   SubCrestaZone          ItemType      mmcode        VehicleType  \
# 0     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle
# 1     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle
# 2     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle
# 3     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle
# 4     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle
# 5     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle
# 6     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle
# 7     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle
# 8     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle
# 9     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle
#
#    RegistrationYear           make  Model  Cylinders  cubiccapacity  \
# 0              2004  MERCEDES-BENZ  E 240        6.0         2597.0
# 1              2004  MERCEDES-BENZ  E 240        6.0         2597.0
# 2              2004  MERCEDES-BENZ  E 240        6.0         2597.0
# 3              2004  MERCEDES-BENZ  E 240        6.0         2597.0
# 4              2004  MERCEDES-BENZ  E 240        6.0         2597.0
# 5              2004  MERCEDES-BENZ  E 240        6.0         2597.0
# 6              2004  MERCEDES-BENZ  E 240        6.0         2597.0
# 7              2004  MERCEDES-BENZ  E 240        6.0         2597.0
# 8              2004  MERCEDES-BENZ  E 240        6.0         2597.0
# 9              2004  MERCEDES-BENZ  E 240        6.0         2597.0
#
#    kilowatts bodytype  NumberOfDoors VehicleIntroDate AlarmImmobiliser  \
# 0      130.0      S/D            4.0       2002-06-01              Yes
# 1      130.0      S/D            4.0       2002-06-01              Yes
# 2      130.0      S/D            4.0       2002-06-01              Yes
# 3      130.0      S/D            4.0       2002-06-01              Yes
# 4      130.0      S/D            4.0       2002-06-01              Yes
# 5      130.0      S/D            4.0       2002-06-01              Yes
# 6      130.0      S/D            4.0       2002-06-01              Yes
# 7      130.0      S/D            4.0       2002-06-01              Yes
# 8      130.0      S/D            4.0       2002-06-01              Yes
# 9      130.0      S/D            4.0       2002-06-01              Yes
#
#   TrackingDevice  CapitalOutstanding  NewVehicle  WrittenOff  Rebuilt  \
# 0             No            119300.0        True       False    False
# 1             No            119300.0        True       False    False
# 2             No            119300.0        True       False    False
# 3             No            119300.0        True       False    False
# 4             No            119300.0        True       False    False
# 5             No            119300.0        True       False    False
# 6             No            119300.0        True       False    False
# 7             No            119300.0        True       False    False
# 8             No            119300.0        True       False    False
# 9             No            119300.0        True       False    False
#
#    Converted  SumInsured TermFrequency  CalculatedPremiumPerTerm  \
# 0      False        0.01       Monthly                   25.0000
# 1      False        0.01       Monthly                   25.0000
# 2      False        0.01       Monthly                   25.0000
# 3      False   119300.00       Monthly                  584.6468
# 4      False   119300.00       Monthly                  584.6468
# 5      False   500000.00       Monthly                   57.5412
# 6      False   500000.00       Monthly                   57.5412
# 7      False   500000.00       Monthly                   57.5412
# 8      False   500000.00       Monthly                   57.5412
# 9      False  5000000.00       Monthly                    1.1508
#
#                      ExcessSelected        CoverCategory            CoverType  \
# 0             Mobility - Windscreen           windscreen           Windscreen
# 1             Mobility - Windscreen           windscreen           Windscreen
# 2             Mobility - Windscreen           windscreen           Windscreen
# 3  Mobility - Metered Taxis - R2000           own damage           Own Damage
# 4  Mobility - Metered Taxis - R2000           own damage           Own Damage
# 5                         No excess          third party          Third Party
# 6                         No excess          third party          Third Party
# 7                         No excess          third party          Third Party
# 8                         No excess          third party          Third Party
# 9                         No excess  passenger liability  Passenger Liability
#
#              CoverGroup              Section                          Product  \
# 0  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 1  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 2  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 3  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 4  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 5  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 6  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 7  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 8  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 9  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
#
#   StatutoryClass StatutoryRiskType  TotalPremium  TotalClaims
# 0     Commercial     IFRS Constant     21.929825          0.0
# 1     Commercial     IFRS Constant     21.929825          0.0
# 2     Commercial     IFRS Constant      0.000000          0.0
# 3     Commercial     IFRS Constant    512.848070          0.0
# 4     Commercial     IFRS Constant      0.000000          0.0
# 5     Commercial     IFRS Constant      3.256435          0.0
# 6     Commercial     IFRS Constant     50.474737          0.0
# 7     Commercial     IFRS Constant     35.332316          0.0
# 8     Commercial     IFRS Constant      0.000000          0.0
# 9     Commercial     IFRS Constant      1.009474          0.0

# %%
# so since most of our datas in gender and martial status is unknown
#lets identify these rows from title column

#normazlize title column to lower case
df['Title'] = df['Title'].str.strip().str.lower()

# %%
# Fill missing/unknown GENDER
def infer_gender(row):
    if row['Gender'] == 'unknown':
        if row['Title'] == 'mr':
            return 'male'
        elif row['Title'] in ['mrs', 'miss', 'ms']:
            return 'female'
    return row['Gender']

# Fill missing/unknown MARITAL STATUS
def infer_marital_status(row):
    if row['MaritalStatus'] == 'unknown':
        if row['Title'] == 'mr':
            return 'unknown'
        elif row['Title'] == 'mrs':
            return 'married'
        elif row['Title'] == 'miss':
            return 'single'
    return row['MaritalStatus']

# %%
# apply the above inference functions
df['Gender'] = df.apply(infer_gender, axis=1)
df['MaritalStatus'] = df.apply(infer_marital_status, axis=1)

# %%
# lets find out the unkonwn again 
print("Remaining unknown Genders:", (df['Gender'] == 'unknown').sum())
print("Remaining unknown Marital Status:", (df['MaritalStatus'] == 'unknown').sum())
# Out:
# Remaining unknown Genders: 810
# Remaining unknown Marital Status: 941888

# %%
# so lets drop un known gendeers and marital status 
# drope column Marital status as it has 99% unknown values
df.drop(columns=['MaritalStatus'], inplace=True)
print("Dropped column: MaritalStatus due to high unknown values.")
# Out:
# Dropped column: MaritalStatus due to high unknown values.

# %%
# delete raws of gender that have unknown valuess
df = df[df['Gender'] != 'unknown']

# %%
# i saw some problem with total claimm values 
# Count total rows
total_rows = len(df)

# Count categories
neg_count = (df["TotalClaims"] < 0).sum()
zero_count = (df["TotalClaims"] == 0).sum()
pos_count = (df["TotalClaims"] > 0).sum()

# Print counts and percentages
print(" Negative TotalClaims:", neg_count, f"({neg_count / total_rows:.2%})")
print(" Zero TotalClaims:    ", zero_count, f"({zero_count / total_rows:.2%})")
print(" Positive TotalClaims:", pos_count, f"({pos_count / total_rows:.2%})")
# Out:
#  Negative TotalClaims: 5 (0.00%)
#  Zero TotalClaims:     995670 (99.72%)
#  Positive TotalClaims: 2773 (0.28%)

# %%
#drop negative total claims
df = df[df['TotalClaims'] >= 0]

# %%
df.head(10)
# Out:
#    RecordID  UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0         0               145249     12827       2015-03-01             True
# 1         1               145249     12827       2015-05-01             True
# 2         2               145249     12827       2015-07-01             True
# 3         3               145255     12827       2015-05-01             True
# 4         4               145255     12827       2015-07-01             True
# 5         5               145247     12827       2015-01-01             True
# 6         6               145247     12827       2015-04-01             True
# 7         7               145247     12827       2015-06-01             True
# 8         8               145247     12827       2015-08-01             True
# 9         9               145245     12827       2015-03-01             True
#
#            LegalType Title                 Bank      AccountType Gender  \
# 0  Close Corporation    mr  first national bank  current account   male
# 1  Close Corporation    mr  first national bank  current account   male
# 2  Close Corporation    mr  first national bank  current account   male
# 3  Close Corporation    mr  first national bank  current account   male
# 4  Close Corporation    mr  first national bank  current account   male
# 5  Close Corporation    mr  first national bank  current account   male
# 6  Close Corporation    mr  first national bank  current account   male
# 7  Close Corporation    mr  first national bank  current account   male
# 8  Close Corporation    mr  first national bank  current account   male
# 9  Close Corporation    mr  first national bank  current account   male
#
#         Country Province  PostalCode MainCrestaZone SubCrestaZone  \
# 0  South Africa  Gauteng        1459      Rand East     Rand East
# 1  South Africa  Gauteng        1459      Rand East     Rand East
# 2  South Africa  Gauteng        1459      Rand East     Rand East
# 3  South Africa  Gauteng        1459      Rand East     Rand East
# 4  South Africa  Gauteng        1459      Rand East     Rand East
# 5  South Africa  Gauteng        1459      Rand East     Rand East
# 6  South Africa  Gauteng        1459      Rand East     Rand East
# 7  South Africa  Gauteng        1459      Rand East     Rand East
# 8  South Africa  Gauteng        1459      Rand East     Rand East
# 9  South Africa  Gauteng        1459      Rand East     Rand East
#
#            ItemType      mmcode        VehicleType  RegistrationYear  \
# 0  Mobility - Motor  44069150.0  Passenger Vehicle              2004
# 1  Mobility - Motor  44069150.0  Passenger Vehicle              2004
# 2  Mobility - Motor  44069150.0  Passenger Vehicle              2004
# 3  Mobility - Motor  44069150.0  Passenger Vehicle              2004
# 4  Mobility - Motor  44069150.0  Passenger Vehicle              2004
# 5  Mobility - Motor  44069150.0  Passenger Vehicle              2004
# 6  Mobility - Motor  44069150.0  Passenger Vehicle              2004
# 7  Mobility - Motor  44069150.0  Passenger Vehicle              2004
# 8  Mobility - Motor  44069150.0  Passenger Vehicle              2004
# 9  Mobility - Motor  44069150.0  Passenger Vehicle              2004
#
#             make  Model  Cylinders  cubiccapacity  kilowatts bodytype  \
# 0  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 1  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 2  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 3  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 4  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 5  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 6  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 7  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 8  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 9  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
#
#    NumberOfDoors VehicleIntroDate AlarmImmobiliser TrackingDevice  \
# 0            4.0       2002-06-01              Yes             No
# 1            4.0       2002-06-01              Yes             No
# 2            4.0       2002-06-01              Yes             No
# 3            4.0       2002-06-01              Yes             No
# 4            4.0       2002-06-01              Yes             No
# 5            4.0       2002-06-01              Yes             No
# 6            4.0       2002-06-01              Yes             No
# 7            4.0       2002-06-01              Yes             No
# 8            4.0       2002-06-01              Yes             No
# 9            4.0       2002-06-01              Yes             No
#
#    CapitalOutstanding  NewVehicle  WrittenOff  Rebuilt  Converted  SumInsured  \
# 0            119300.0        True       False    False      False        0.01
# 1            119300.0        True       False    False      False        0.01
# 2            119300.0        True       False    False      False        0.01
# 3            119300.0        True       False    False      False   119300.00
# 4            119300.0        True       False    False      False   119300.00
# 5            119300.0        True       False    False      False   500000.00
# 6            119300.0        True       False    False      False   500000.00
# 7            119300.0        True       False    False      False   500000.00
# 8            119300.0        True       False    False      False   500000.00
# 9            119300.0        True       False    False      False  5000000.00
#
#   TermFrequency  CalculatedPremiumPerTerm                    ExcessSelected  \
# 0       Monthly                   25.0000             Mobility - Windscreen
# 1       Monthly                   25.0000             Mobility - Windscreen
# 2       Monthly                   25.0000             Mobility - Windscreen
# 3       Monthly                  584.6468  Mobility - Metered Taxis - R2000
# 4       Monthly                  584.6468  Mobility - Metered Taxis - R2000
# 5       Monthly                   57.5412                         No excess
# 6       Monthly                   57.5412                         No excess
# 7       Monthly                   57.5412                         No excess
# 8       Monthly                   57.5412                         No excess
# 9       Monthly                    1.1508                         No excess
#
#          CoverCategory            CoverType            CoverGroup  \
# 0           windscreen           Windscreen  Comprehensive - Taxi
# 1           windscreen           Windscreen  Comprehensive - Taxi
# 2           windscreen           Windscreen  Comprehensive - Taxi
# 3           own damage           Own Damage  Comprehensive - Taxi
# 4           own damage           Own Damage  Comprehensive - Taxi
# 5          third party          Third Party  Comprehensive - Taxi
# 6          third party          Third Party  Comprehensive - Taxi
# 7          third party          Third Party  Comprehensive - Taxi
# 8          third party          Third Party  Comprehensive - Taxi
# 9  passenger liability  Passenger Liability  Comprehensive - Taxi
#
#                Section                          Product StatutoryClass  \
# 0  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 1  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 2  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 3  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 4  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 5  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 6  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 7  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 8  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 9  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
#
#   StatutoryRiskType  TotalPremium  TotalClaims
# 0     IFRS Constant     21.929825          0.0
# 1     IFRS Constant     21.929825          0.0
# 2     IFRS Constant      0.000000          0.0
# 3     IFRS Constant    512.848070          0.0
# 4     IFRS Constant      0.000000          0.0
# 5     IFRS Constant      3.256435          0.0
# 6     IFRS Constant     50.474737          0.0
# 7     IFRS Constant     35.332316          0.0
# 8     IFRS Constant      0.000000          0.0
# 9     IFRS Constant      1.009474          0.0

# %%
df.to_csv('../data/cleaned_machineLearningRating.csv', index=False)
print("\n Cleaning complete. Cleaned data saved to: cleaned_machineLearningRating.csv")
# Out:
#  Cleaning complete. Cleaned data saved to: cleaned_machineLearningRating.csv
